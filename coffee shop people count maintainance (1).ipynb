# %%
import cv2
from tracker import *
import pandas as pd
import numpy as np
import math
from ultralytics import YOLO

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\KanugulBharath Kumar\Downloads\peoplecounteryolov8-main\peoplecounteryolov8-main

# %%
import os
print(os.listdir())
# Out:
# ['.ipynb_checkpoints', 'coco.txt', 'coffee shop people count maintainance.ipynb', 'download.txt', 'main.py', 'peoplecount1', 'peoplecount1.mp4', 'tracker.py', 'Untitled.ipynb', 'Untitled1.ipynb', 'Untitled2-Copy1.ipynb', 'yolov8s.pt', '__pycache__']

# %%
tracker = projection()

model = YOLO('yolov8s.pt')

area1 = [(312, 388),(289, 390),(474, 469),(497, 462)]
area2 = [(279, 392),(250,397) ,(423,477),(454, 469)]


def RGB(event, x, y, flags, param):
    
    if event == cv2.EVENT_MOUSEMOVE:
        colorsBGR = [x, y]
        print(colorsBGR)


cv2.namedWindow('RGB')
cv2.setMouseCallback('RGB', RGB)

cap = cv2.VideoCapture('peoplecount1.mp4')

my_file = open("coco.txt", "r")
data = my_file.read()
class_list = data.split("\n")

count = 0

people_entering = {}
people_exiting = {}
entering = set()
exiting = set()

while True:
    ret, frame = cap.read()
    if not ret:
        break
    count += 1
    if count % 2 != 0:
        continue
    frame = cv2.resize(frame, (1020, 500))
    results = model.predict(frame)
    a = results[0].boxes.data
    px = pd.DataFrame(a).astype("float")
    list = []

    for index, row in px.iterrows():
        x1 = int(row[0])
        y1 = int(row[1])
        x2 = int(row[2])
        y2 = int(row[3])
        d = int(row[5])
        c = class_list[d]
        if 'person' in c:
            list.append([x1, y1, x2, y2])
    bbox_id = tracker.update(list)
    for bbox in bbox_id:
        x3, y3, x4, y4, id = bbox

        # into the hotel
        result = cv2.pointPolygonTest(np.array(area2, np.int32), ((x4, y4)), False)
        if result >= 0:
            people_entering[id] = (x4, y4)
            cv2.rectangle(frame, (x3, y3), (x4, y4), (0, 0, 255), 2)
        if id in people_entering:
            result1 = cv2.pointPolygonTest(np.array(area1, np.int32), ((x4, y4)), False)
            if result1 >= 0:
                cv2.rectangle(frame, (x3, y3), (x4, y4), (0, 255, 0), 2)
                cv2.circle(frame, (x4, y4), 5, (255, 0, 255), -1)
                cv2.putText(frame, str(id), (x3, y3), cv2.FONT_HERSHEY_COMPLEX, (0.5), (255, 255, 255), 1)
                entering.add(id)

    #out of hotel
        result2 = cv2.pointPolygonTest(np.array(area1, np.int32), ((x4, y4)), False)
        if result2 >= 0:
            people_exiting[id] = (x4, y4)
            cv2.rectangle(frame, (x3, y3), (x4, y4), (0, 255, 0), 2)
        if id in people_exiting:
            result3 = cv2.pointPolygonTest(np.array(area2, np.int32), ((x4, y4)), False)
            if result3 >= 0:
                cv2.rectangle(frame, (x3, y3), (x4, y4), (255, 0, 0), 2)
                cv2.circle(frame, (x4, y4), 5, (255, 0, 255), -1)
                cv2.putText(frame, str(id), (x3, y3), cv2.FONT_HERSHEY_COMPLEX, (0.5), (255, 255, 255), 1)
                exiting.add(id)

    cv2.polylines(frame, [np.array(area1, np.int32)], True, (255, 0, 0), 2)
    cv2.putText(frame, str('entryROI'), (504, 471), cv2.FONT_HERSHEY_COMPLEX, (0.5), (0, 0, 0), 1)

    cv2.polylines(frame, [np.array(area2, np.int32)], True, (255, 0, 0), 2)
    cv2.putText(frame, str('exitROI'), (466, 485), cv2.FONT_HERSHEY_COMPLEX, (0.5), (0, 0, 0), 1)
    cv2.putText(frame, "THE COFFEE SHOP", (20, 50), cv2.FONT_HERSHEY_COMPLEX, 1, (0, 255, 255), 2)

    print(len(entering))
    print(len(exiting))
    ccc=len(entering)
    vvv=len(exiting)
    ccc1=ccc-vvv
    cv2.putText(frame, str('Current customer count:'), (40, 120), cv2.FONT_HERSHEY_COMPLEX, (0.8), (0, 255, 255), 3)
    #cv2.putText(frame, str('Max capacity:4'), (40,147), cv2.FONT_HERSHEY_COMPLEX, (0.8), (0, 255, 255), 3)
    if ccc1>=4:
        cv2.putText(frame, str(ccc1), (80, 160), cv2.FONT_HERSHEY_COMPLEX, (0.8), (0, 0, 255), 3)
    
    else:    
        cv2.putText(frame, str(ccc1), (80, 160), cv2.FONT_HERSHEY_COMPLEX, (0.8), (255, 0, 255), 3)
    #cv2.putText(frame, str('Max capacity:4'), (40,147), cv2.FONT_HERSHEY_COMPLEX, (0.8), (0, 255, 255), 3)


    cv2.imshow("window", frame)
    if cv2.waitKey(1) & 0xFF == 27:
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 320x640 1 car, 110.4ms
# Speed: 12.0ms preprocess, 110.4ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 0
# 0
#
# 0: 320x640 1 car, 123.8ms
# Speed: 2.0ms preprocess, 123.8ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 0
# 0
#
# 0: 320x640 1 person, 1 car, 101.8ms
# Speed: 1.0ms preprocess, 101.8ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 0
# 0
#
# 0: 320x640 1 person, 1 car, 110.2ms
# Speed: 1.0ms preprocess, 110.2ms inference, 15.6ms postprocess per image at shape (1, 3, 320, 640)
# 0
# 0
#
# 0: 320x640 1 person, 1 car, 136.4ms
# Speed: 0.0ms preprocess, 136.4ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
# 0
# 0
#
# 0: 320x640 1 person, 1 car, 138.2ms
# Speed: 2.0ms preprocess, 138.2ms inference, 0.9ms postprocess per image at shape (1, 3, 320, 640)
# 0
# 0
#
# 0: 320x640 1 person, 2 cars, 106.8ms
# Speed: 1.0ms preprocess, 106.8ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 0
# 0
#
# 0: 320x640 1 person, 2 cars, 149.1ms
# Speed: 0.0ms preprocess, 149.1ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 0
# 0
#
# 0: 320x640 1 person, 2 cars, 133.2ms
# Speed: 0.0ms preprocess, 133.2ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 0
# 0
#
# 0: 320x640 1 person, 2 cars, 122.1ms
# Speed: 1.0ms preprocess, 122.1ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 0
# 0
#
# 0: 320x640 1 person, 2 cars, 129.1ms
# Speed: 1.0ms preprocess, 129.1ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 0
# 0
#
# 0: 320x640 1 person, 2 cars, 126.8ms
# Speed: 2.7ms preprocess, 126.8ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 0
# 0
#
# 0: 320x640 1 person, 2 cars, 109.9ms
# Speed: 0.0ms preprocess, 109.9ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 0
# 0
#
# 0: 320x640 1 person, 2 cars, 93.5ms
# Speed: 1.0ms preprocess, 93.5ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 0
# 0
#
# 0: 320x640 1 person, 1 car, 1 potted plant, 129.2ms
# Speed: 0.0ms preprocess, 129.2ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 0
# 0
#
# 0: 320x640 1 person, 2 cars, 133.0ms
# Speed: 2.0ms preprocess, 133.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 0
# 0
#
# 0: 320x640 1 person, 2 cars, 126.1ms
# Speed: 0.0ms preprocess, 126.1ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 0
# 0
#
# 0: 320x640 1 person, 2 cars, 110.0ms
# Speed: 1.0ms preprocess, 110.0ms inference, 15.5ms postprocess per image at shape (1, 3, 320, 640)
# 0
# 0
#
# 0: 320x640 1 person, 1 car, 172.6ms
# Speed: 2.0ms preprocess, 172.6ms inference, 1.8ms postprocess per image at shape (1, 3, 320, 640)
# 0
# 0
#
# 0: 320x640 3 persons, 2 cars, 160.8ms
# Speed: 0.0ms preprocess, 160.8ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 0
# 0
#
# 0: 320x640 3 persons, 2 cars, 129.5ms
# Speed: 1.0ms preprocess, 129.5ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 0
# 0
#
# 0: 320x640 2 persons, 2 cars, 102.4ms
# Speed: 1.0ms preprocess, 102.4ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 0
# 0
#
# 0: 320x640 3 persons, 1 car, 135.9ms
# Speed: 1.0ms preprocess, 135.9ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 0
# 0
#
# 0: 320x640 4 persons, 118.0ms
# Speed: 15.9ms preprocess, 118.0ms inference, 15.2ms postprocess per image at shape (1, 3, 320, 640)
# 0
# 0
#
# 0: 320x640 4 persons, 133.4ms
# Speed: 0.0ms preprocess, 133.4ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 0
# 0
#
# 0: 320x640 3 persons, 142.5ms
# Speed: 2.0ms preprocess, 142.5ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 0
# 0
#
# 0: 320x640 4 persons, 87.9ms
# Speed: 2.0ms preprocess, 87.9ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 0
# 0
#
# 0: 320x640 3 persons, 135.1ms
# Speed: 1.0ms preprocess, 135.1ms inference, 15.6ms postprocess per image at shape (1, 3, 320, 640)
# 0
# 0
#
# 0: 320x640 3 persons, 129.5ms
# Speed: 1.0ms preprocess, 129.5ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 1
# 0
#
# 0: 320x640 4 persons, 119.9ms
# Speed: 1.0ms preprocess, 119.9ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 1
# 0
#
# 0: 320x640 3 persons, 99.5ms
# Speed: 1.3ms preprocess, 99.5ms inference, 15.6ms postprocess per image at shape (1, 3, 320, 640)
# 1
# 0
#
# 0: 320x640 3 persons, 115.8ms
# Speed: 2.0ms preprocess, 115.8ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 1
# 0
#
# 0: 320x640 3 persons, 1 car, 129.6ms
# Speed: 16.4ms preprocess, 129.6ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 1
# 0
#
# 0: 320x640 3 persons, 112.9ms
# Speed: 1.0ms preprocess, 112.9ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 1
# 0
#
# 0: 320x640 3 persons, 114.8ms
# Speed: 2.0ms preprocess, 114.8ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 1
# 0
#
# 0: 320x640 4 persons, 128.0ms
# Speed: 2.0ms preprocess, 128.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 1
# 0
#
# 0: 320x640 4 persons, 141.3ms
# Speed: 1.0ms preprocess, 141.3ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 1
# 0
#
# 0: 320x640 3 persons, 126.6ms
# Speed: 1.0ms preprocess, 126.6ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 1
# 0
#
# 0: 320x640 5 persons, 146.7ms
# Speed: 1.6ms preprocess, 146.7ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 1
# 0
#
# 0: 320x640 2 persons, 1 handbag, 127.7ms
# Speed: 1.0ms preprocess, 127.7ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 1
# 0
#
# 0: 320x640 2 persons, 128.0ms
# Speed: 2.0ms preprocess, 128.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 1
# 0
#
# 0: 320x640 2 persons, 129.0ms
# Speed: 1.2ms preprocess, 129.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 1
# 0
#
# 0: 320x640 2 persons, 82.8ms
# Speed: 1.6ms preprocess, 82.8ms inference, 15.5ms postprocess per image at shape (1, 3, 320, 640)
# 1
# 0
#
# 0: 320x640 2 persons, 78.2ms
# Speed: 1.0ms preprocess, 78.2ms inference, 15.6ms postprocess per image at shape (1, 3, 320, 640)
# 1
# 0
#
# 0: 320x640 2 persons, 120.5ms
# Speed: 1.0ms preprocess, 120.5ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 1
# 0
#
# 0: 320x640 2 persons, 125.2ms
# Speed: 1.0ms preprocess, 125.2ms inference, 15.7ms postprocess per image at shape (1, 3, 320, 640)
# 1
# 0
#
# 0: 320x640 2 persons, 1 tv, 124.4ms
# Speed: 1.0ms preprocess, 124.4ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 1
# 0
#
# 0: 320x640 2 persons, 133.4ms
# Speed: 1.0ms preprocess, 133.4ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
# 1
# 0
#
# 0: 320x640 2 persons, 131.0ms
# Speed: 1.0ms preprocess, 131.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 1
# 0
#
# 0: 320x640 2 persons, 125.7ms
# Speed: 1.0ms preprocess, 125.7ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 1
# 0
#
# 0: 320x640 2 persons, 115.4ms
# Speed: 2.0ms preprocess, 115.4ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 2 persons, 114.9ms
# Speed: 1.9ms preprocess, 114.9ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 2 persons, 1 backpack, 142.8ms
# Speed: 0.0ms preprocess, 142.8ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 2 persons, 140.7ms
# Speed: 1.5ms preprocess, 140.7ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 2 persons, 133.8ms
# Speed: 2.0ms preprocess, 133.8ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 2 persons, 81.8ms
# Speed: 1.0ms preprocess, 81.8ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 2 persons, 113.8ms
# Speed: 0.0ms preprocess, 113.8ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 2 persons, 121.5ms
# Speed: 1.0ms preprocess, 121.5ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 2 persons, 127.6ms
# Speed: 0.0ms preprocess, 127.6ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 2 persons, 124.0ms
# Speed: 1.0ms preprocess, 124.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 2 persons, 136.2ms
# Speed: 2.0ms preprocess, 136.2ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 1 person, 122.2ms
# Speed: 1.0ms preprocess, 122.2ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 1 person, 142.0ms
# Speed: 0.0ms preprocess, 142.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 1 person, 130.7ms
# Speed: 2.0ms preprocess, 130.7ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 1 person, 128.3ms
# Speed: 2.0ms preprocess, 128.3ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 1 person, 113.6ms
# Speed: 1.6ms preprocess, 113.6ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 1 person, 126.8ms
# Speed: 0.0ms preprocess, 126.8ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 1 person, 111.9ms
# Speed: 0.0ms preprocess, 111.9ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 1 person, 140.2ms
# Speed: 0.0ms preprocess, 140.2ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 1 person, 130.8ms
# Speed: 1.7ms preprocess, 130.8ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 1 person, 145.3ms
# Speed: 2.8ms preprocess, 145.3ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 1 person, 93.3ms
# Speed: 1.0ms preprocess, 93.3ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 1 person, 93.3ms
# Speed: 2.0ms preprocess, 93.3ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 1 person, 116.8ms
# Speed: 2.0ms preprocess, 116.8ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 1 person, 125.5ms
# Speed: 2.5ms preprocess, 125.5ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 1 person, 123.5ms
# Speed: 1.1ms preprocess, 123.5ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 1 person, 113.7ms
# Speed: 1.9ms preprocess, 113.7ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 1 person, 129.9ms
# Speed: 1.1ms preprocess, 129.9ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 1 person, 122.0ms
# Speed: 2.0ms preprocess, 122.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 1 person, 142.8ms
# Speed: 2.0ms preprocess, 142.8ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 1 person, 143.0ms
# Speed: 1.8ms preprocess, 143.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 1 person, 145.4ms
# Speed: 0.0ms preprocess, 145.4ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 1 person, 135.9ms
# Speed: 2.0ms preprocess, 135.9ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 1 person, 152.3ms
# Speed: 1.0ms preprocess, 152.3ms inference, 1.7ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 1 person, 132.7ms
# Speed: 0.0ms preprocess, 132.7ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 1 person, 147.6ms
# Speed: 0.0ms preprocess, 147.6ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 1 person, 150.7ms
# Speed: 0.0ms preprocess, 150.7ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 1 person, 138.7ms
# Speed: 2.0ms preprocess, 138.7ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 1 person, 132.6ms
# Speed: 1.9ms preprocess, 132.6ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 1 person, 149.7ms
# Speed: 0.0ms preprocess, 149.7ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 1 person, 133.1ms
# Speed: 16.7ms preprocess, 133.1ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 1 person, 121.9ms
# Speed: 1.0ms preprocess, 121.9ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 1 person, 130.2ms
# Speed: 0.0ms preprocess, 130.2ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 1 person, 135.6ms
# Speed: 2.0ms preprocess, 135.6ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 1 person, 147.5ms
# Speed: 1.9ms preprocess, 147.5ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
# [982, 93]
#
# 0: 320x640 1 person, 148.8ms
# Speed: 2.0ms preprocess, 148.8ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
# [816, 238]
# [816, 238]
#
# 0: 320x640 1 person, 138.5ms
# Speed: 2.0ms preprocess, 138.5ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
# [896, 87]
#
# 0: 320x640 1 person, 125.8ms
# Speed: 1.0ms preprocess, 125.8ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
# [938, 35]
#
# 0: 320x640 1 person, 121.0ms
# Speed: 2.0ms preprocess, 121.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
# [969, 6]
#
# 0: 320x640 1 person, 129.5ms
# Speed: 2.0ms preprocess, 129.5ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 1 person, 128.6ms
# Speed: 1.0ms preprocess, 128.6ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 1 person, 148.3ms
# Speed: 1.0ms preprocess, 148.3ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 1 person, 142.1ms
# Speed: 2.0ms preprocess, 142.1ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 1 person, 137.2ms
# Speed: 2.0ms preprocess, 137.2ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 1 person, 150.2ms
# Speed: 0.0ms preprocess, 150.2ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 1 person, 164.0ms
# Speed: 0.0ms preprocess, 164.0ms inference, 1.6ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 1 person, 149.2ms
# Speed: 2.4ms preprocess, 149.2ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 1 person, 110.6ms
# Speed: 0.0ms preprocess, 110.6ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 1 person, 158.5ms
# Speed: 0.0ms preprocess, 158.5ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 1 person, 143.6ms
# Speed: 1.1ms preprocess, 143.6ms inference, 15.6ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 1 person, 173.6ms
# Speed: 0.0ms preprocess, 173.6ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 1 person, 164.0ms
# Speed: 2.2ms preprocess, 164.0ms inference, 15.6ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 1 person, 145.4ms
# Speed: 0.0ms preprocess, 145.4ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 1 person, 141.8ms
# Speed: 0.0ms preprocess, 141.8ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 1 person, 154.0ms
# Speed: 0.0ms preprocess, 154.0ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 1 person, 138.7ms
# Speed: 2.0ms preprocess, 138.7ms inference, 17.0ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 2 persons, 141.2ms
# Speed: 1.0ms preprocess, 141.2ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 1 person, 135.2ms
# Speed: 2.0ms preprocess, 135.2ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 1 person, 133.8ms
# Speed: 1.0ms preprocess, 133.8ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 1 person, 127.6ms
# Speed: 2.0ms preprocess, 127.6ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 1 person, 1 car, 99.5ms
# Speed: 1.0ms preprocess, 99.5ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 2 persons, 115.9ms
# Speed: 1.0ms preprocess, 115.9ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 2 persons, 125.9ms
# Speed: 1.0ms preprocess, 125.9ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 1 person, 124.0ms
# Speed: 2.0ms preprocess, 124.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 1 person, 127.5ms
# Speed: 1.0ms preprocess, 127.5ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 3 persons, 128.7ms
# Speed: 15.0ms preprocess, 128.7ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 1 person, 129.5ms
# Speed: 1.0ms preprocess, 129.5ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 1 person, 122.0ms
# Speed: 2.0ms preprocess, 122.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 1 person, 153.5ms
# Speed: 1.0ms preprocess, 153.5ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 1 person, 132.5ms
# Speed: 2.0ms preprocess, 132.5ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 1 person, 140.8ms
# Speed: 1.8ms preprocess, 140.8ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 1 person, 134.0ms
# Speed: 2.0ms preprocess, 134.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 1 person, 133.3ms
# Speed: 2.0ms preprocess, 133.3ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 3 persons, 119.8ms
# Speed: 2.0ms preprocess, 119.8ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 1 person, 136.7ms
# Speed: 2.0ms preprocess, 136.7ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 1 person, 135.5ms
# Speed: 1.9ms preprocess, 135.5ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 1 person, 142.4ms
# Speed: 2.4ms preprocess, 142.4ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 1 person, 135.7ms
# Speed: 1.0ms preprocess, 135.7ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 2 persons, 103.0ms
# Speed: 1.0ms preprocess, 103.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 1 person, 126.2ms
# Speed: 2.0ms preprocess, 126.2ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 1 person, 134.6ms
# Speed: 1.0ms preprocess, 134.6ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 1 person, 97.4ms
# Speed: 2.0ms preprocess, 97.4ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 1 person, 1 backpack, 132.7ms
# Speed: 1.1ms preprocess, 132.7ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 1 person, 147.1ms
# Speed: 0.0ms preprocess, 147.1ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 1 person, 1 backpack, 145.8ms
# Speed: 2.0ms preprocess, 145.8ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 1 person, 1 backpack, 120.1ms
# Speed: 2.0ms preprocess, 120.1ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 2 persons, 1 backpack, 121.8ms
# Speed: 1.0ms preprocess, 121.8ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 1 person, 1 backpack, 152.2ms
# Speed: 14.5ms preprocess, 152.2ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 1 person, 1 backpack, 131.7ms
# Speed: 0.9ms preprocess, 131.7ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 1 person, 1 backpack, 129.8ms
# Speed: 0.0ms preprocess, 129.8ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 2 persons, 1 backpack, 124.9ms
# Speed: 1.1ms preprocess, 124.9ms inference, 15.6ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 2 persons, 1 car, 1 backpack, 127.8ms
# Speed: 2.0ms preprocess, 127.8ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 3 persons, 1 car, 123.4ms
# Speed: 1.0ms preprocess, 123.4ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 2 persons, 1 car, 1 handbag, 152.7ms
# Speed: 2.0ms preprocess, 152.7ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 2 persons, 1 car, 2 handbags, 164.2ms
# Speed: 2.0ms preprocess, 164.2ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 2 persons, 2 cars, 1 handbag, 168.0ms
# Speed: 0.6ms preprocess, 168.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 2 persons, 2 cars, 1 handbag, 147.9ms
# Speed: 2.0ms preprocess, 147.9ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 2 persons, 2 cars, 2 handbags, 148.7ms
# Speed: 1.2ms preprocess, 148.7ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 1 person, 2 cars, 2 handbags, 151.1ms
# Speed: 0.0ms preprocess, 151.1ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 1 person, 3 cars, 3 handbags, 135.1ms
# Speed: 14.1ms preprocess, 135.1ms inference, 13.8ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 1 person, 3 cars, 1 handbag, 153.6ms
# Speed: 0.4ms preprocess, 153.6ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 2 persons, 3 cars, 1 handbag, 160.4ms
# Speed: 0.0ms preprocess, 160.4ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 2 persons, 1 car, 1 handbag, 115.1ms
# Speed: 1.0ms preprocess, 115.1ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 2 persons, 1 car, 1 handbag, 157.2ms
# Speed: 2.4ms preprocess, 157.2ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 2 persons, 1 car, 2 handbags, 121.8ms
# Speed: 2.0ms preprocess, 121.8ms inference, 16.5ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 2 persons, 3 cars, 132.8ms
# Speed: 2.0ms preprocess, 132.8ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 2 persons, 2 cars, 2 handbags, 137.4ms
# Speed: 2.0ms preprocess, 137.4ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 2 persons, 2 cars, 2 handbags, 139.4ms
# Speed: 1.0ms preprocess, 139.4ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 2 persons, 1 car, 2 handbags, 122.6ms
# Speed: 2.0ms preprocess, 122.6ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 2 persons, 2 handbags, 149.8ms
# Speed: 1.8ms preprocess, 149.8ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 2 persons, 1 handbag, 153.6ms
# Speed: 0.0ms preprocess, 153.6ms inference, 0.9ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 2 persons, 148.6ms
# Speed: 2.0ms preprocess, 148.6ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 2 persons, 155.4ms
# Speed: 2.0ms preprocess, 155.4ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 2 persons, 1 tv, 151.4ms
# Speed: 2.0ms preprocess, 151.4ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 2 persons, 1 handbag, 167.0ms
# Speed: 0.0ms preprocess, 167.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 2 persons, 1 handbag, 166.6ms
# Speed: 0.2ms preprocess, 166.6ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 2 persons, 1 handbag, 147.9ms
# Speed: 0.0ms preprocess, 147.9ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 2 persons, 2 handbags, 133.4ms
# Speed: 0.0ms preprocess, 133.4ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 2 persons, 1 handbag, 121.6ms
# Speed: 1.0ms preprocess, 121.6ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 2 persons, 2 handbags, 140.2ms
# Speed: 2.0ms preprocess, 140.2ms inference, 14.2ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 4 persons, 2 handbags, 1 tv, 165.6ms
# Speed: 0.0ms preprocess, 165.6ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 4 persons, 1 handbag, 157.7ms
# Speed: 0.0ms preprocess, 157.7ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
# 2
# 0
#
# 0: 320x640 2 persons, 2 handbags, 163.7ms
# Speed: 13.3ms preprocess, 163.7ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
# 3
# 0
#
# 0: 320x640 2 persons, 1 handbag, 147.3ms
# Speed: 2.0ms preprocess, 147.3ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 3
# 0
#
# 0: 320x640 2 persons, 1 handbag, 121.2ms
# Speed: 2.0ms preprocess, 121.2ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 3
# 0
#
# 0: 320x640 2 persons, 1 handbag, 133.5ms
# Speed: 1.0ms preprocess, 133.5ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 3
# 0
#
# 0: 320x640 2 persons, 1 handbag, 1 refrigerator, 141.2ms
# Speed: 1.0ms preprocess, 141.2ms inference, 13.2ms postprocess per image at shape (1, 3, 320, 640)
# 3
# 0
#
# 0: 320x640 2 persons, 1 handbag, 1 refrigerator, 153.5ms
# Speed: 13.4ms preprocess, 153.5ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 3
# 0
#
# 0: 320x640 2 persons, 1 handbag, 145.9ms
# Speed: 2.0ms preprocess, 145.9ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 3
# 0
#
# 0: 320x640 2 persons, 139.0ms
# Speed: 2.0ms preprocess, 139.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 3
# 0
#
# 0: 320x640 2 persons, 114.9ms
# Speed: 2.0ms preprocess, 114.9ms inference, 15.6ms postprocess per image at shape (1, 3, 320, 640)
# 3
# 0
#
# 0: 320x640 2 persons, 1 handbag, 164.0ms
# Speed: 1.8ms preprocess, 164.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 3
# 0
#
# 0: 320x640 2 persons, 1 handbag, 113.8ms
# Speed: 2.0ms preprocess, 113.8ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 3
# 0
#
# 0: 320x640 2 persons, 1 handbag, 148.9ms
# Speed: 0.0ms preprocess, 148.9ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 3
# 0
#
# 0: 320x640 2 persons, 154.9ms
# Speed: 1.6ms preprocess, 154.9ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 3
# 0
#
# 0: 320x640 2 persons, 114.0ms
# Speed: 1.9ms preprocess, 114.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 3
# 0
#
# 0: 320x640 2 persons, 1 handbag, 138.2ms
# Speed: 1.0ms preprocess, 138.2ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
# 3
# 0
#
# 0: 320x640 2 persons, 1 handbag, 135.0ms
# Speed: 2.0ms preprocess, 135.0ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
# 3
# 0
#
# 0: 320x640 2 persons, 132.7ms
# Speed: 1.0ms preprocess, 132.7ms inference, 14.8ms postprocess per image at shape (1, 3, 320, 640)
# 3
# 0
#
# 0: 320x640 2 persons, 156.2ms
# Speed: 2.0ms preprocess, 156.2ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 3
# 0
#
# 0: 320x640 2 persons, 143.7ms
# Speed: 2.0ms preprocess, 143.7ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 3
# 0
#
# 0: 320x640 2 persons, 129.4ms
# Speed: 2.4ms preprocess, 129.4ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 3
# 0
#
# 0: 320x640 2 persons, 132.7ms
# Speed: 2.0ms preprocess, 132.7ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 3
# 0
#
# 0: 320x640 2 persons, 144.2ms
# Speed: 2.0ms preprocess, 144.2ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
# 3
# 0
#
# 0: 320x640 2 persons, 165.0ms
# Speed: 2.0ms preprocess, 165.0ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
# 3
# 0
#
# 0: 320x640 1 person, 139.5ms
# Speed: 1.1ms preprocess, 139.5ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 3
# 0
#
# 0: 320x640 1 person, 120.0ms
# Speed: 2.0ms preprocess, 120.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 3
# 0
#
# 0: 320x640 1 person, 151.2ms
# Speed: 2.0ms preprocess, 151.2ms inference, 13.5ms postprocess per image at shape (1, 3, 320, 640)
# 3
# 0
#
# 0: 320x640 1 person, 138.4ms
# Speed: 1.0ms preprocess, 138.4ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 3
# 0
#
# 0: 320x640 1 person, 136.6ms
# Speed: 2.0ms preprocess, 136.6ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 3
# 0
#
# 0: 320x640 1 person, 172.9ms
# Speed: 0.0ms preprocess, 172.9ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
# 4
# 0
#
# 0: 320x640 1 person, 153.8ms
# Speed: 2.0ms preprocess, 153.8ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
# 4
# 0
#
# 0: 320x640 1 person, 116.7ms
# Speed: 1.9ms preprocess, 116.7ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 4
# 0
#
# 0: 320x640 1 person, 138.6ms
# Speed: 2.0ms preprocess, 138.6ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 4
# 0
#
# 0: 320x640 1 person, 155.8ms
# Speed: 2.0ms preprocess, 155.8ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 4
# 0
#
# 0: 320x640 1 person, 150.3ms
# Speed: 14.9ms preprocess, 150.3ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 4
# 0
#
# 0: 320x640 1 person, 151.9ms
# Speed: 2.8ms preprocess, 151.9ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
# 4
# 0
#
# 0: 320x640 1 person, 166.7ms
# Speed: 0.0ms preprocess, 166.7ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 4
# 0
#
# 0: 320x640 1 person, 152.7ms
# Speed: 0.0ms preprocess, 152.7ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 4
# 0
#
# 0: 320x640 1 person, 142.7ms
# Speed: 1.0ms preprocess, 142.7ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
# 4
# 0
#
# 0: 320x640 1 person, 167.1ms
# Speed: 2.0ms preprocess, 167.1ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 4
# 0
#
# 0: 320x640 1 person, 166.4ms
# Speed: 0.0ms preprocess, 166.4ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 4
# 0
#
# 0: 320x640 1 person, 172.0ms
# Speed: 0.0ms preprocess, 172.0ms inference, 2.1ms postprocess per image at shape (1, 3, 320, 640)
# 4
# 0
#
# 0: 320x640 1 person, 166.5ms
# Speed: 0.0ms preprocess, 166.5ms inference, 14.8ms postprocess per image at shape (1, 3, 320, 640)
# 4
# 0
#
# 0: 320x640 1 person, 129.8ms
# Speed: 2.2ms preprocess, 129.8ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 4
# 0
#
# 0: 320x640 1 person, 166.7ms
# Speed: 1.0ms preprocess, 166.7ms inference, 1.9ms postprocess per image at shape (1, 3, 320, 640)
# 4
# 0
#
# 0: 320x640 1 person, 133.0ms
# Speed: 0.0ms preprocess, 133.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 4
# 0
#
# 0: 320x640 1 person, 167.2ms
# Speed: 0.0ms preprocess, 167.2ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 4
# 0
#
# 0: 320x640 1 person, 131.6ms
# Speed: 1.0ms preprocess, 131.6ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 4
# 0
#
# 0: 320x640 1 person, 152.0ms
# Speed: 2.4ms preprocess, 152.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 4
# 0
#
# 0: 320x640 (no detections), 151.6ms
# Speed: 14.4ms preprocess, 151.6ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 4
# 0
#
# 0: 320x640 (no detections), 160.1ms
# Speed: 0.0ms preprocess, 160.1ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
# 4
# 0
#
# 0: 320x640 (no detections), 129.7ms
# Speed: 0.0ms preprocess, 129.7ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 4
# 0
#
# 0: 320x640 (no detections), 132.5ms
# Speed: 2.0ms preprocess, 132.5ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 4
# 0
#
# 0: 320x640 (no detections), 161.2ms
# Speed: 2.0ms preprocess, 161.2ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
# 4
# 0
#
# 0: 320x640 (no detections), 159.5ms
# Speed: 1.0ms preprocess, 159.5ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 4
# 0
#
# 0: 320x640 (no detections), 130.4ms
# Speed: 1.0ms preprocess, 130.4ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 4
# 0
#
# 0: 320x640 (no detections), 131.7ms
# Speed: 1.0ms preprocess, 131.7ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 4
# 0
#
# 0: 320x640 (no detections), 157.5ms
# Speed: 2.1ms preprocess, 157.5ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
# 4
# 0
#
# 0: 320x640 (no detections), 166.4ms
# Speed: 0.0ms preprocess, 166.4ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 4
# 0
#
# 0: 320x640 (no detections), 174.9ms
# Speed: 0.0ms preprocess, 174.9ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
# 4
# 0
#
# 0: 320x640 (no detections), 166.4ms
# Speed: 0.0ms preprocess, 166.4ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 4
# 0
#
# 0: 320x640 (no detections), 118.2ms
# Speed: 1.0ms preprocess, 118.2ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 4
# 0
#
# 0: 320x640 (no detections), 149.1ms
# Speed: 2.2ms preprocess, 149.1ms inference, 0.8ms postprocess per image at shape (1, 3, 320, 640)
# 4
# 0
#
# 0: 320x640 (no detections), 168.6ms
# Speed: 0.0ms preprocess, 168.6ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 4
# 0
#
# 0: 320x640 (no detections), 166.9ms
# Speed: 0.0ms preprocess, 166.9ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 4
# 0
#
# 0: 320x640 (no detections), 166.5ms
# Speed: 0.0ms preprocess, 166.5ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 4
# 0
#
# 0: 320x640 (no detections), 155.8ms
# Speed: 2.0ms preprocess, 155.8ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
# 4
# 0
#
# 0: 320x640 (no detections), 118.5ms
# Speed: 1.0ms preprocess, 118.5ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 4
# 0
#
# 0: 320x640 (no detections), 128.5ms
# Speed: 0.0ms preprocess, 128.5ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 4
# 0
#
# 0: 320x640 (no detections), 144.8ms
# Speed: 1.5ms preprocess, 144.8ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 4
# 0
#
# 0: 320x640 1 person, 107.8ms
# Speed: 2.3ms preprocess, 107.8ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 4
# 0
#
# 0: 320x640 1 person, 149.6ms
# Speed: 3.0ms preprocess, 149.6ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 4
# 0
#
# 0: 320x640 1 person, 147.5ms
# Speed: 2.0ms preprocess, 147.5ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 4
# 0
#
# 0: 320x640 1 person, 141.2ms
# Speed: 2.3ms preprocess, 141.2ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 4
# 0
#
# 0: 320x640 1 person, 137.6ms
# Speed: 2.0ms preprocess, 137.6ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
# 4
# 0
#
# 0: 320x640 1 person, 118.9ms
# Speed: 1.6ms preprocess, 118.9ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 4
# 0
#
# 0: 320x640 1 person, 148.2ms
# Speed: 0.0ms preprocess, 148.2ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
# 4
# 0
#
# 0: 320x640 1 person, 127.9ms
# Speed: 0.0ms preprocess, 127.9ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 4
# 0
#
# 0: 320x640 1 person, 130.4ms
# Speed: 2.4ms preprocess, 130.4ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 4
# 0
#
# 0: 320x640 1 person, 1 tv, 153.2ms
# Speed: 2.0ms preprocess, 153.2ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 4
# 0
#
# 0: 320x640 1 person, 1 tv, 135.3ms
# Speed: 1.0ms preprocess, 135.3ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 4
# 0
#
# 0: 320x640 1 person, 134.6ms
# Speed: 1.9ms preprocess, 134.6ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 4
# 0
#
# 0: 320x640 1 person, 133.4ms
# Speed: 0.0ms preprocess, 133.4ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 4
# 0
#
# 0: 320x640 1 person, 158.6ms
# Speed: 2.0ms preprocess, 158.6ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
# 4
# 0
#
# 0: 320x640 1 person, 175.8ms
# Speed: 0.0ms preprocess, 175.8ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
# 4
# 0
#
# 0: 320x640 1 person, 136.7ms
# Speed: 2.9ms preprocess, 136.7ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 4
# 0
#
# 0: 320x640 1 person, 125.0ms
# Speed: 1.0ms preprocess, 125.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 4
# 0
#
# 0: 320x640 1 person, 123.1ms
# Speed: 2.0ms preprocess, 123.1ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 4
# 0
#
# 0: 320x640 1 person, 151.7ms
# Speed: 2.5ms preprocess, 151.7ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 4
# 0
#
# 0: 320x640 1 person, 140.7ms
# Speed: 2.0ms preprocess, 140.7ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 4
# 0
#
# 0: 320x640 1 person, 111.4ms
# Speed: 1.0ms preprocess, 111.4ms inference, 15.7ms postprocess per image at shape (1, 3, 320, 640)
# 4
# 1
#
# 0: 320x640 1 person, 149.6ms
# Speed: 0.0ms preprocess, 149.6ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 4
# 1
#
# 0: 320x640 1 person, 131.7ms
# Speed: 2.5ms preprocess, 131.7ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 4
# 1
#
# 0: 320x640 1 person, 132.2ms
# Speed: 1.5ms preprocess, 132.2ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 4
# 1
#
# 0: 320x640 1 person, 133.9ms
# Speed: 2.6ms preprocess, 133.9ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 4
# 1
#
# 0: 320x640 1 person, 167.9ms
# Speed: 2.0ms preprocess, 167.9ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 4
# 1
#
# 0: 320x640 1 person, 159.5ms
# Speed: 0.0ms preprocess, 159.5ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 4
# 1
#
# 0: 320x640 1 person, 136.6ms
# Speed: 0.0ms preprocess, 136.6ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 4
# 1
#
# 0: 320x640 2 persons, 150.3ms
# Speed: 0.0ms preprocess, 150.3ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
# 4
# 1
#
# 0: 320x640 2 persons, 133.0ms
# Speed: 2.4ms preprocess, 133.0ms inference, 15.6ms postprocess per image at shape (1, 3, 320, 640)
# 4
# 1
#
# 0: 320x640 2 persons, 129.3ms
# Speed: 0.0ms preprocess, 129.3ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 4
# 1
#
# 0: 320x640 2 persons, 167.7ms
# Speed: 0.0ms preprocess, 167.7ms inference, 1.3ms postprocess per image at shape (1, 3, 320, 640)
# 4
# 1
#
# 0: 320x640 2 persons, 180.1ms
# Speed: 0.0ms preprocess, 180.1ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 4
# 1
#
# 0: 320x640 2 persons, 136.2ms
# Speed: 2.0ms preprocess, 136.2ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 4
# 1
#
# 0: 320x640 2 persons, 129.7ms
# Speed: 2.7ms preprocess, 129.7ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 4
# 1
#
# 0: 320x640 2 persons, 116.7ms
# Speed: 2.0ms preprocess, 116.7ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 4
# 1
#
# 0: 320x640 2 persons, 116.0ms
# Speed: 1.0ms preprocess, 116.0ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 4
# 1
#
# 0: 320x640 2 persons, 125.1ms
# Speed: 1.0ms preprocess, 125.1ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 4
# 1
#
# 0: 320x640 2 persons, 1 skateboard, 130.7ms
# Speed: 2.0ms preprocess, 130.7ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 4
# 1
#
# 0: 320x640 2 persons, 152.6ms
# Speed: 2.0ms preprocess, 152.6ms inference, 15.6ms postprocess per image at shape (1, 3, 320, 640)
# 4
# 1
#
# 0: 320x640 2 persons, 144.5ms
# Speed: 0.0ms preprocess, 144.5ms inference, 2.0ms postprocess per image at shape (1, 3, 320, 640)
# 4
# 1
#
# 0: 320x640 3 persons, 1 skateboard, 147.5ms
# Speed: 2.6ms preprocess, 147.5ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 4
# 1
#
# 0: 320x640 (no detections), 109.9ms
# Speed: 9.6ms preprocess, 109.9ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 4
# 1
#
# 0: 320x640 (no detections), 160.7ms
# Speed: 0.0ms preprocess, 160.7ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
# 4
# 1
#
# 0: 320x640 (no detections), 94.6ms
# Speed: 2.0ms preprocess, 94.6ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 640)
# 4
# 1

# %%
class projection:
    def __init__(self):
        self.center_points = {}
        self.id_count = 0


    def update(self, objects_rect):
        objects_bbs_ids = []

        for rect in objects_rect:
            x, y, w, h = rect
            cx = (x + x + w) // 2
            cy = (y + y + h) // 2

            same_object_detected = False
            for id, pt in self.center_points.items():
                dist = math.hypot(cx - pt[0], cy - pt[1])

                if dist < 35:
                    self.center_points[id] = (cx, cy)
                    objects_bbs_ids.append([x, y, w, h, id])
                    same_object_detected = True
                    break

            if same_object_detected is False:
                self.center_points[self.id_count] = (cx, cy)
                objects_bbs_ids.append([x, y, w, h, self.id_count])
                self.id_count += 1

        new_center_points = {}
        for obj_bb_id in objects_bbs_ids:
            _, _, _, _, object_id = obj_bb_id
            center = self.center_points[object_id]
            new_center_points[object_id] = center

        self.center_points = new_center_points.copy()
        return objects_bbs_ids
